# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from seq_queries.utils import read_pkl, write_pkl

# %%
data = read_pkl("data/importance_sampling/shakespeare/mc_importance_estimate_art_thou?_1024_10000s.pkl")
sns.kdeplot(data)
plt.xlabel("Marginal probability of <space>")
plt.title("""Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'
Number of sample means: 1024
Samples per mean: 10,000""")
# Out:
# Text(0.5, 1.0, "Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'\nNumber of sample means: 1024\nSamples per mean: 10,000")

# %%
data = read_pkl("data/importance_sampling/shakespeare/mc_importance_estimate_art_thou?_1024_1000s.pkl")
sns.kdeplot(data)
plt.xlabel("Marginal probability of <space>")
plt.title("""Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'
Number of sample means: 1024
Samples per mean: 1,000""")
# Out:
# Text(0.5, 1.0, "Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'\nNumber of sample means: 1024\nSamples per mean: 1,000")

# %%
sns.kdeplot(data)
plt.xlabel("Marginal probability of <space>")
plt.title("""Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'
Number of sample means: 256
Samples per mean: 1000""")
# Out:
# Text(0.5, 1.0, "Seq (hist|seq|pred|extra): 'how old a|rt|<space>|thou?'\nNumber of sample means: 256\nSamples per mean: 1000")
